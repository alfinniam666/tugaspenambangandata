# %%
import numpy as ip
import seaborn as sea
import matplotlib.pyplot as mat
from scipy import stats
import pandas as data

for i in range(4):
    cek1=data.read_csv("ujicoba2.csv",usecols=[i])
    c1= cek1.count()
    print("Jumlah sel data = ",c1)
    print(" ")
    o1= cek1.mode()
    print("modus = ",o1)
    print(" ")
    m1= cek1.mean()
    print("mean = ",m1)
    print(" ")
    e1= cek1.median()
    print("median = ",e1)
    print(" ")
    s1=cek1.std()
    print("standar deviasi =",s1)
    print(" ")
    w1= cek1.skew()
    print("skewwnes = ",s1)
    print(" ")
    Q1= cek1.quantile(0.25)
    print("Kuartil awal = ",Q1)
    print(" ")
    Q2= cek1.quantile(0.50)
    print("Kuartil tengah = ",Q2)
    print(" ")
    Q3= cek1.quantile(0.75)
    print("Kuartil tengah = ",Q3)
    print(" ")
    sea.distplot(cek1);
# Out:
# Jumlah sel data =  nomer peserta    500
# dtype: int64
#
# modus =     nomer peserta
# 0             43
#
# mean =  nomer peserta    246.738
# dtype: float64
#
# median =  nomer peserta    244.0
# dtype: float64
#
# standar deviasi = nomer peserta    141.727282
# dtype: float64
#
# skewwnes =  nomer peserta    141.727282
# dtype: float64
#
# Kuartil awal =  nomer peserta    118.0
# Name: 0.25, dtype: float64
#
# Kuartil tengah =  nomer peserta    244.0
# Name: 0.5, dtype: float64
#
# Kuartil tengah =  nomer peserta    369.0
# Name: 0.75, dtype: float64
#
# Jumlah sel data =  hadiah undian    500
# dtype: int64
#
# modus =     hadiah undian
# 0            333
#
# mean =  hadiah undian    252.844
# dtype: float64
#
# median =  hadiah undian    255.5
# dtype: float64
#
# standar deviasi = hadiah undian    148.600268
# dtype: float64
#
# skewwnes =  hadiah undian    148.600268
# dtype: float64
#
# Kuartil awal =  hadiah undian    125.5
# Name: 0.25, dtype: float64
#
# Kuartil tengah =  hadiah undian    255.5
# Name: 0.5, dtype: float64
#
# Kuartil tengah =  hadiah undian    379.0
# Name: 0.75, dtype: float64
#
# Jumlah sel data =  umur peserta    500
# dtype: int64
#
# modus =     umur peserta
# 0           383
#
# mean =  umur peserta    252.1
# dtype: float64
#
# median =  umur peserta    255.0
# dtype: float64
#
# standar deviasi = umur peserta    142.80938
# dtype: float64
#
# skewwnes =  umur peserta    142.80938
# dtype: float64
#
# Kuartil awal =  umur peserta    123.0
# Name: 0.25, dtype: float64
#
# Kuartil tengah =  umur peserta    255.0
# Name: 0.5, dtype: float64
#
# Kuartil tengah =  umur peserta    378.25
# Name: 0.75, dtype: float64
#
# Jumlah sel data =  banyaknya mencoba    500
# dtype: int64
#
# modus =     banyaknya mencoba
# 0                 74
# 1                259
# 2                351
# 3                355
# 4                384
# 5                451
#
# mean =  banyaknya mencoba    247.998
# dtype: float64
#
# median =  banyaknya mencoba    244.5
# dtype: float64
#
# standar deviasi = banyaknya mencoba    147.336683
# dtype: float64
#
# skewwnes =  banyaknya mencoba    147.336683
# dtype: float64
#
# Kuartil awal =  banyaknya mencoba    112.75
# Name: 0.25, dtype: float64
#
# Kuartil tengah =  banyaknya mencoba    244.5
# Name: 0.5, dtype: float64
#
# Kuartil tengah =  banyaknya mencoba    375.25
# Name: 0.75, dtype: float64
